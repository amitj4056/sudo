# %%
from gingerit.gingerit import GingerIt

# %%
text = 'they is good boy'

# %%
parser = GingerIt()

# %%
print(parser.parse(text))
# Out:
# {'text': 'they is good boy', 'result': ' They are good boys', 'corrections': [{'text': 'the', 'correct': 'They', 'definition': None}, {'text': 'i', 'correct': 'are', 'definition': None}, {'text': 'good bo', 'correct': 'good boys', 'definition': None}]}

# %%
print(text.lower())
# Out:
# they is good boy

# %%
print(parser.parse(text)['result'])
# Out:
#  They are good boys

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6e230a00a763> in <module>
# ----> 1 nltk.download()
#
# ~/anaconda/lib/python3.7/site-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     771             if download_dir is not None:
#     772                 self._download_dir = download_dir
# --> 773             self._interactive_download()
#     774             return True
#     775
#
# ~/anaconda/lib/python3.7/site-packages/nltk/downloader.py in _interactive_download(self)
#    1121         if TKINTER:
#    1122             try:
# -> 1123                 DownloaderGUI(self).mainloop()
#    1124             except TclError:
#    1125                 DownloaderShell(self).run()
#
# ~/anaconda/lib/python3.7/site-packages/nltk/downloader.py in mainloop(self, *args, **kwargs)
#    1943
#    1944     def mainloop(self, *args, **kwargs):
# -> 1945         self.top.mainloop(*args, **kwargs)
#    1946
#    1947     # /////////////////////////////////////////////////////////////////
#
# ~/anaconda/lib/python3.7/tkinter/__init__.py in mainloop(self, n)
#    1281     def mainloop(self, n=0):
#    1282         """Call the mainloop of Tk."""
# -> 1283         self.tk.mainloop(n)
#    1284     def quit(self):
#    1285         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:
